# %% [markdown]
# # ACA Distillation on AntMaze
#
# This notebook installs the project, downloads an AntMaze dataset through Minari, trains the ACA-style teacher plus distilled student, and evaluates latency vs success.

# %%
# !pip install -q -e .[dev]
# !pip install -q -e .[rl,viz]

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

# %%
# !minari download D4RL/antmaze/medium-diverse-v1

# %%
# !python scripts/train_antmaze.py train --config configs/antmaze_medium.yaml

# %%
# !python -m aca_distill.cli eval --config configs/antmaze_medium.yaml --checkpoint runs/antmaze-medium/checkpoints/latest.pt
